# %%
import warnings
import pathlib, os
from jack.tooling import io as io_tool
from jack.ranking import weak
from typing import List, Tuple
import plotly.figure_factory as ff
import numpy as np
import copy
warnings.filterwarnings('ignore')

# %% [markdown]
# > Let's load the test dataset first

# %%
data_dir = pathlib.Path.home() / "Dataset"
filename = "test_df"

rename_columns = {"Title": "text", "Code": "label"}

# %%
df = next(io_tool.load(data_dir, filename, ext=".csv", rename_columns=rename_columns))

# %%
df.head()
# Out:
#                                   text       label
# 0             sr business director usa  11-2021.00
# 1        retail team leader glebe road  41-2031.00
# 2              deployment technician i  15-1151.00
# 3  ecm project manager oconus position  15-1142.00
# 4                 business analyst lvl  13-1111.00

# %% [markdown]
# > In `explore.ipynb` we have already replaced `label` code with textual description. Let's reuse it to here again. For simplicity copy/paste the result

# %%
mapping = {
    '11-1021.00': 'General and Operations Managers',
    '11-2021.00': 'Marketing Managers',
    '11-2022.00': 'Sales Managers',
    '11-3031.02': 'Financial Managers, Branch or Department',
    '13-1111.00': 'Management Analysts',
    '13-2051.00': 'Financial Analysts',
    '15-1121.00': 'Computer Systems Analysts',
    '15-1122.00': 'Information Security Analysts',
    '15-1132.00': 'Software Developers, Applications',
    '15-1133.00': 'Software Developers, Systems Software',
    '15-1134.00': 'Web Developers',
    '15-1142.00': 'Network and Computer Systems Administrators',
    '15-1151.00': 'Computer User Support Specialists',
    '29-1141.00': 'Registered Nurses',
    '31-1014.00': 'Nursing Assistants',
    '33-3021.06': 'Intelligence Analysts',
    '41-2031.00': 'Retail Salespersons',
    '43-4051.00': 'Customer Service Representatives',
    '49-3023.02': 'Automotive Specialty Technicians',
    '49-9071.00': 'Maintenance and Repair Workers, General',
    '53-3032.00': 'Heavy and Tractor-Trailer Truck Drivers'
 }

# %%
df = df.replace({"label": dict(mapping)})

# %%
df.head()
# Out:
#                                   text  \
# 0             sr business director usa
# 1        retail team leader glebe road
# 2              deployment technician i
# 3  ecm project manager oconus position
# 4                 business analyst lvl
#
#                                          label
# 0                           Marketing Managers
# 1                          Retail Salespersons
# 2            Computer User Support Specialists
# 3  Network and Computer Systems Administrators
# 4                          Management Analysts

# %% [markdown]
# Now let's initialize `ranker`. It requires `label list` as a parameter.

# %%
label_list = list(mapping.values())

# %%
ranker = weak.WeakRanker(label_list=label_list)

# %% [markdown]
# > Now let's iterate over the test set and harvest the fruits :-)

# %%
response = []

# %%
for ex in iter(df.to_dict(orient="records")):
    query = ex["text"]
    label = ex["label"]
    ans, score = ranker.rank(query)
    res = (query, ans, score, label)
    response.append(res)

# %%
response
# Out:
# [('sr business director usa',
#   'Software Developers, Applications',
#   1.5555330598502624,
#   'Marketing Managers'),
#  ('retail team leader glebe road',
#   'General and Operations Managers',
#   3.3990241647287007,
#   'Retail Salespersons'),
#  ('deployment technician i',
#   None,
#   1.4696588113054703,
#   'Computer User Support Specialists'),
#  ('ecm project manager oconus position',
#   'Software Developers, Systems Software',
#   2.397671562828017,
#   'Network and Computer Systems Administrators'),
#  ('business analyst lvl', None, 0.745062938695187, 'Management Analysts'),
#  ('licensed social worker social service director',
#   'Registered Nurses',
#   1.8316976450671931,
#   'Customer Service Representatives'),
#  ('ground systems engineering management',
#   'Software Developers, Systems Software',
#   2.3030528630893343,
#   'Management Analysts'),
#  ('cre relationship manager',
#   'Sales Managers',
#   2.313351911856767,
#   'Sales Managers'),
#  ('infrastructure operations engineer',
#   'Network and Computer Systems Administrators',
#   2.3144912791287435,
#   'Network and Computer Systems Administrators'),
#  ('sr analyst capital markets',
#   'Financial Managers, Branch or Department',
#   2.5288976561174743,
#   'Financial Managers, Branch or Department'),
#  ('aegis bmd systems engineer',
#   'Software Developers, Systems Software',
#   2.274681763675681,
#   'Software Developers, Systems Software'),
#  ('public sector program and portfolio management manager',
#   'Management Analysts',
#   1.8152360620376449,
#   'Management Analysts'),
#  ('smb sales snr manager',
#   'Sales Managers',
#   4.161684470502553,
#   'Sales Managers'),
#  ('circuit implementation program manager',
#   'Management Analysts',
#   1.5634104593763296,
#   'Web Developers'),
#  ('director program usa dss',
#   None,
#   0.9143223251925106,
#   'General and Operations Managers'),
#  ('sales specialist call',
#   'Customer Service Representatives',
#   2.2981980387781342,
#   'Financial Managers, Branch or Department'),
#  ('satellite operations engineer multiple positions ds',
#   None,
#   0.8131251473755968,
#   'Software Developers, Systems Software'),
#  ('senior research engineer cyber wargaming',
#   'Software Developers, Systems Software',
#   2.249475453637694,
#   'Software Developers, Applications'),
#  ('jr systems administrator',
#   'Network and Computer Systems Administrators',
#   2.317165352808762,
#   'Network and Computer Systems Administrators'),
#  ('maintenance shop technician c',
#   'Automotive Specialty Technicians',
#   3.275902359677899,
#   'Automotive Specialty Technicians'),
#  ('red cell intelligence analyst',
#   None,
#   1.4899698513464437,
#   'Information Security Analysts'),
#  ('master software engineer usa',
#   'Software Developers, Applications',
#   4.140523815377116,
#   'Software Developers, Applications'),
#  ('sr business process analyst knowledge management specialist',
#   'Computer Systems Analysts',
#   1.7490085998892633,
#   'Information Security Analysts'),
#  ('principal citrix system engineer',
#   'Network and Computer Systems Administrators',
#   2.374827629187701,
#   'Network and Computer Systems Administrators'),
#  ('aoc ws network technician',
#   'Network and Computer Systems Administrators',
#   1.8159216822965816,
#   'Network and Computer Systems Administrators'),
#  ('configuration management specialist government',
#   'Management Analysts',
#   1.6479071241865888,
#   'Computer User Support Specialists'),
#  ('security practice manager',
#   'Marketing Managers',
#   1.5058798432521503,
#   'Information Security Analysts'),
#  ('chief of party cambodia horticulture',
#   'General and Operations Managers',
#   3.586511582661636,
#   'Computer User Support Specialists'),
#  ('nsrwa cls program incumbent',
#   None,
#   1.283101852638731,
#   'Software Developers, Applications'),
#  ('net centric security security engineer',
#   'Information Security Analysts',
#   2.3166120807376998,
#   'Software Developers, Applications'),
#  ('of care education coordinator',
#   'Registered Nurses',
#   3.155320872595874,
#   'Nursing Assistants'),
#  ('patient service rep full',
#   'Registered Nurses',
#   2.4060706227989774,
#   'Registered Nurses'),
#  ('senior acquisition analyst',
#   'Management Analysts',
#   2.287143049758717,
#   'Computer Systems Analysts'),
#  ('senior linguist serbo croatian',
#   'Computer Systems Analysts',
#   3.970658947494331,
#   'Computer Systems Analysts'),
#  ('fall coop internship electrical engineering technology majors',
#   None,
#   0.9214045043107362,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('entry mid level engineer',
#   None,
#   0.8228757859244575,
#   'Maintenance and Repair Workers, General'),
#  ('senior web applications developer drupal php',
#   'Web Developers',
#   3.4265662890736888,
#   'Software Developers, Applications'),
#  ('edi systems development manager',
#   'Marketing Managers',
#   2.168934202633104,
#   'Financial Analysts'),
#  ('sr c developer risk analytics',
#   'Software Developers, Applications',
#   3.325064216540122,
#   'Software Developers, Systems Software'),
#  ('customer service rep hr',
#   'Customer Service Representatives',
#   1.6693868233577664,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('social collaboration community manager',
#   'Marketing Managers',
#   1.515294520267486,
#   'Intelligence Analysts'),
#  ('medical social worker prn',
#   'Registered Nurses',
#   3.3334070458266654,
#   'Registered Nurses'),
#  ('flooring department manager',
#   'General and Operations Managers',
#   2.9764426971753943,
#   'Software Developers, Applications'),
#  ('follow on development fod security administrator ts city',
#   None,
#   0.7496014374592619,
#   'Information Security Analysts'),
#  ('direct support professional place',
#   'Customer Service Representatives',
#   2.56494085589633,
#   'Customer Service Representatives'),
#  ('deloitte encore program senior sap finance consultant',
#   'Management Analysts',
#   1.6706389774676704,
#   'Computer Systems Analysts'),
#  ('strategic account manager',
#   'Sales Managers',
#   4.03901607155313,
#   'Sales Managers'),
#  ('assoc help desk technician ts sci reqd',
#   'Network and Computer Systems Administrators',
#   2.766862061413642,
#   'Information Security Analysts'),
#  ('housekeeping shift supervisor janelia farm research',
#   'General and Operations Managers',
#   1.5594900507941123,
#   'Nursing Assistants'),
#  ('registered nurse inova internal travel rn pediatrics peds',
#   'Registered Nurses',
#   3.419590893687016,
#   'Registered Nurses'),
#  ('fpga reverse engineer',
#   'Software Developers, Systems Software',
#   1.5313252637512274,
#   'Software Developers, Applications'),
#  ('business strategy analyst senior',
#   'Management Analysts',
#   1.5505817937506676,
#   'Intelligence Analysts'),
#  ('part certified nursing assistant cna',
#   'Nursing Assistants',
#   3.6915733775720376,
#   'Nursing Assistants'),
#  ('employee occupational health nurse inova occupational health william',
#   'Registered Nurses',
#   1.896005370328146,
#   'Registered Nurses'),
#  ('software delivery manager',
#   None,
#   1.4771990052143709,
#   'Software Developers, Applications'),
#  ('operating room nursing internship registered nurse',
#   'Registered Nurses',
#   2.7689216131303698,
#   'Registered Nurses'),
#  ('certified nursing assistant personal care aide eastern henrico',
#   'Nursing Assistants',
#   3.628260156608678,
#   'Nursing Assistants'),
#  ('senior cost analyst',
#   'Financial Analysts',
#   1.5738443064363483,
#   'Management Analysts'),
#  ('team leader outpatient clinics',
#   'General and Operations Managers',
#   2.399935234986613,
#   'Management Analysts'),
#  ('marketing proposal manager',
#   'Marketing Managers',
#   1.514604563470867,
#   'Sales Managers'),
#  ('retail support signing team associate part s the fashion at pentagon city',
#   'Retail Salespersons',
#   2.8835099922879577,
#   'Customer Service Representatives'),
#  ('o m technician wolf',
#   'Network and Computer Systems Administrators',
#   2.4259418450478645,
#   'Maintenance and Repair Workers, General'),
#  ('real analyst', None, 0.7959447425485054, 'Marketing Managers'),
#  ('software engineer dinfos web admin and development',
#   'Software Developers, Applications',
#   3.257865723242785,
#   'Software Developers, Applications'),
#  ('accounting assistant needed for busy accounting team',
#   'Financial Managers, Branch or Department',
#   3.508419195352418,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('nex sales clerk minimart',
#   'Retail Salespersons',
#   4.446066960450588,
#   'Retail Salespersons'),
#  ('program manager physical security',
#   'Information Security Analysts',
#   2.370185817835035,
#   'Information Security Analysts'),
#  ('epic certified clindoc stork sr technical specialist',
#   'Computer Systems Analysts',
#   4.3663404777667205,
#   'Computer Systems Analysts'),
#  ('maintenance technician iii mon fri',
#   'Maintenance and Repair Workers, General',
#   1.5664921704999721,
#   'Maintenance and Repair Workers, General'),
#  ('cmh museum support job',
#   None,
#   0.78570902685971,
#   'Software Developers, Systems Software'),
#  ('liaison integration and production support specialist p',
#   'Computer User Support Specialists',
#   1.6317871167678175,
#   'Intelligence Analysts'),
#  ('deep learning engineer',
#   'Software Developers, Systems Software',
#   2.212462591468337,
#   'Software Developers, Systems Software'),
#  ('project services administrator',
#   None,
#   1.4439178868774234,
#   'Management Analysts'),
#  ('scheduling registration rep inova urgent care part t',
#   'Registered Nurses',
#   3.399764134403618,
#   'Customer Service Representatives'),
#  ('registered nurse emergency room',
#   'Registered Nurses',
#   4.341104319929422,
#   'Registered Nurses'),
#  ('store pricing specialist ft',
#   'Financial Analysts',
#   1.556009152962781,
#   'Nursing Assistants'),
#  ('amazon web services cloud architect senior',
#   'Software Developers, Applications',
#   2.6727527968558036,
#   'Software Developers, Systems Software'),
#  ('management intern',
#   None,
#   1.4937438410378072,
#   'Software Developers, Systems Software'),
#  ('treasury supervisor',
#   'Financial Analysts',
#   2.192724578529988,
#   'Financial Analysts'),
#  ('canvass event direct marketing',
#   'Marketing Managers',
#   1.5559473649493927,
#   'Customer Service Representatives'),
#  ('dir pop hlth initiatives', None, 1.4666468520870808, 'Marketing Managers'),
#  ('engineering technician ii ongoing',
#   None,
#   0.8966048212357067,
#   'Network and Computer Systems Administrators'),
#  ('presales technical architect',
#   'Information Security Analysts',
#   2.323399493122173,
#   'General and Operations Managers'),
#  ('acute care nurse practitioner thoracic cardiovascular icu full varied shift msn np rn',
#   'Registered Nurses',
#   3.6315035023482034,
#   'Registered Nurses'),
#  ('satellite expertise engineer senior',
#   'Software Developers, Systems Software',
#   2.3918388876270313,
#   'Computer Systems Analysts'),
#  ('field service voip engineer northern',
#   'Network and Computer Systems Administrators',
#   2.5743394943717726,
#   'Network and Computer Systems Administrators'),
#  ('sr princ administrator system with polygraph',
#   'Network and Computer Systems Administrators',
#   2.609774446580313,
#   'Network and Computer Systems Administrators'),
#  ('business resources coordinator',
#   None,
#   1.4936057075005795,
#   'Financial Analysts'),
#  ('test and evaluation t e support',
#   'Software Developers, Systems Software',
#   2.6076102093429325,
#   'Software Developers, Systems Software'),
#  ('nurse disease management i telecommute kt',
#   'Registered Nurses',
#   2.743409173383614,
#   'Registered Nurses'),
#  ('director finance job',
#   'Financial Managers, Branch or Department',
#   1.5321092317033722,
#   'Financial Analysts'),
#  ('network communications manager',
#   'Network and Computer Systems Administrators',
#   2.3376615154174774,
#   'Software Developers, Applications'),
#  ('services technician i', None, 1.4824395582272234, 'Registered Nurses'),
#  ('staff officer administrative',
#   'Intelligence Analysts',
#   2.3621858566207408,
#   'Intelligence Analysts'),
#  ('sr security engineer and forensic analyst',
#   'Information Security Analysts',
#   2.3277476311299337,
#   'Information Security Analysts'),
#  ('incident response threat intrusion analyst',
#   'Information Security Analysts',
#   2.6020458874602257,
#   'Information Security Analysts'),
#  ('dod healthcare patient administration subject matter expert',
#   None,
#   0.9073332118785972,
#   'Computer Systems Analysts'),
#  ('customer service representative work from',
#   'Customer Service Representatives',
#   1.7366728420351447,
#   'Financial Managers, Branch or Department'),
#  ('human services assistant ii shelter advocate',
#   None,
#   0.8442854828797797,
#   'Registered Nurses'),
#  ('senior project manager government',
#   'Software Developers, Applications',
#   1.5232003810428663,
#   'Management Analysts'),
#  ('regional team driver she',
#   'Heavy and Tractor-Trailer Truck Drivers',
#   4.311818126067855,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('senior av technician',
#   None,
#   1.3680702969878424,
#   'Computer User Support Specialists'),
#  ('unix linux administrator',
#   'Network and Computer Systems Administrators',
#   3.4529371550808667,
#   'Network and Computer Systems Administrators'),
#  ('international affairs team',
#   None,
#   1.453519428313402,
#   'Intelligence Analysts'),
#  ('technician electrician maintenance shift',
#   'Automotive Specialty Technicians',
#   1.6244922525702217,
#   'Maintenance and Repair Workers, General'),
#  ('sr osp network engineer designing troubleshooting permits',
#   'Network and Computer Systems Administrators',
#   3.7993744481091625,
#   'Software Developers, Systems Software'),
#  ('registered nurse progressive surgical unit telemetry shift',
#   'Registered Nurses',
#   3.601834945047431,
#   'Nursing Assistants'),
#  ('rn case manager health and hospice',
#   'Registered Nurses',
#   4.425902348905525,
#   'Registered Nurses'),
#  ('billing assistant',
#   'Financial Analysts',
#   2.1871573852092854,
#   'Network and Computer Systems Administrators'),
#  ('thermalspray technician', None, 1.286744104131753, 'Management Analysts'),
#  ('mainframe technical support analyst entry level',
#   'Computer User Support Specialists',
#   1.6918587836892836,
#   'Computer Systems Analysts'),
#  ('nsw boat division personal property custodian p',
#   'Intelligence Analysts',
#   1.8303447095900556,
#   'Management Analysts'),
#  ('sr area manager aws support',
#   'General and Operations Managers',
#   1.5530054804096227,
#   'Sales Managers'),
#  ('tech instructor course developer spawar ttl',
#   'Registered Nurses',
#   1.5321412989677867,
#   'Computer Systems Analysts'),
#  ('tree care groundsman bucket truck operator climber positions',
#   'Heavy and Tractor-Trailer Truck Drivers',
#   2.2740680740993002,
#   'Maintenance and Repair Workers, General'),
#  ('registered nurse behavioral health nurse',
#   'Nursing Assistants',
#   2.723697743202208,
#   'Registered Nurses'),
#  ('sr contract analyst federal', None, 1.4591402636882718, 'Sales Managers'),
#  ('solutions architect senior',
#   'Software Developers, Applications',
#   2.3966364352430896,
#   'Software Developers, Systems Software'),
#  ('service desk manager customer satisfaction ts clearance',
#   'Financial Managers, Branch or Department',
#   1.5984970186612815,
#   'Information Security Analysts'),
#  ('organizational strategy and business process consultant mid',
#   'Management Analysts',
#   3.4791158844112644,
#   'Management Analysts'),
#  ('sr reporting architect',
#   'Network and Computer Systems Administrators',
#   1.508824486047018,
#   'Software Developers, Applications'),
#  ('registered nurse graduate msicu',
#   'Registered Nurses',
#   4.206547430991725,
#   'Nursing Assistants'),
#  ('senior vmware administrator p',
#   'Network and Computer Systems Administrators',
#   2.4850725774869886,
#   'Software Developers, Systems Software'),
#  ('network engineer department of state server engineer',
#   'Network and Computer Systems Administrators',
#   1.5596438700615274,
#   'Network and Computer Systems Administrators'),
#  ('software engineer rest api',
#   'Software Developers, Applications',
#   3.4018133061131177,
#   'Software Developers, Applications'),
#  ('information assurance engineer p jwac',
#   'Network and Computer Systems Administrators',
#   3.4144074948794882,
#   'Information Security Analysts'),
#  ('director shared services', None, 0.8321658715810192, 'Sales Managers'),
#  ('rn cardiovascular intensive care unit',
#   'Registered Nurses',
#   2.5206430076583666,
#   'Registered Nurses'),
#  ('director cyber programs', None, 0.7781658032769135, 'Marketing Managers'),
#  ('peritoneal dialysis registered nurse rn tidewater',
#   'Registered Nurses',
#   4.435480512833069,
#   'Registered Nurses'),
#  ('customer support associate',
#   None,
#   0.7916441417424543,
#   'Retail Salespersons'),
#  ('director federal partners', None, 1.4958026133729014, 'Sales Managers'),
#  ('federal project analyst and agile coach',
#   'Management Analysts',
#   1.5629970482882456,
#   'Computer Systems Analysts'),
#  ('sr business performance analyst cyber',
#   'Management Analysts',
#   2.355200552886633,
#   'Information Security Analysts'),
#  ('sr principal engineer systems ts sci required',
#   'Network and Computer Systems Administrators',
#   2.6739051388969224,
#   'Software Developers, Systems Software'),
#  ('charge capture coordinator',
#   'Marketing Managers',
#   2.190386459826169,
#   'Registered Nurses'),
#  ('spacecraft operations engineer',
#   'Software Developers, Systems Software',
#   3.1580262700766712,
#   'Software Developers, Systems Software'),
#  ('seasonal tax services group senior associate',
#   'Financial Managers, Branch or Department',
#   4.259329942127922,
#   'Financial Managers, Branch or Department'),
#  ('implementation specialist specialty',
#   'Management Analysts',
#   1.5385875426346112,
#   'Management Analysts'),
#  ('project manager career development',
#   None,
#   0.7479034277426713,
#   'Intelligence Analysts'),
#  ('senior business developer',
#   'Software Developers, Applications',
#   2.212993606266336,
#   'Marketing Managers'),
#  ('senior business manager office of the cio',
#   None,
#   0.8260914021828571,
#   'General and Operations Managers'),
#  ('mechanic technician level a',
#   'Automotive Specialty Technicians',
#   3.280848646825522,
#   'Automotive Specialty Technicians'),
#  ('senior release engineer',
#   'Software Developers, Applications',
#   3.8247592083332465,
#   'Software Developers, Applications'),
#  ('retail sales manager falls church',
#   'Registered Nurses',
#   1.688147189881552,
#   'Financial Managers, Branch or Department'),
#  ('administrator telecom networking',
#   'Network and Computer Systems Administrators',
#   2.331957259812945,
#   'Network and Computer Systems Administrators'),
#  ('provider network management director ltss bh idd care',
#   None,
#   0.9017976930167682,
#   'Management Analysts'),
#  ('business change manager',
#   'Management Analysts',
#   3.19079855980884,
#   'Management Analysts'),
#  ('svp marketing communications',
#   'Marketing Managers',
#   3.1918890753149505,
#   'Marketing Managers'),
#  ('nex sales clerk consumables',
#   'Retail Salespersons',
#   4.384611957238482,
#   'Retail Salespersons'),
#  ('human services program coordinator',
#   'Marketing Managers',
#   2.278306160475908,
#   'Registered Nurses'),
#  ('amazon data facility manager',
#   None,
#   0.7943393038437556,
#   'Computer User Support Specialists'),
#  ('senior business analyst',
#   None,
#   0.7478946603506977,
#   'General and Operations Managers'),
#  ('student trainee investigative support assistant',
#   'General and Operations Managers',
#   1.5171995411883774,
#   'Software Developers, Systems Software'),
#  ('supervisor operational risk',
#   'Financial Managers, Branch or Department',
#   1.6187060614300788,
#   'Information Security Analysts'),
#  ('plumbing service tech plumber',
#   'Automotive Specialty Technicians',
#   1.5074767918008904,
#   'Maintenance and Repair Workers, General'),
#  ('document management specialist',
#   'Information Security Analysts',
#   1.6247194072146067,
#   'Software Developers, Applications'),
#  ('program manager job',
#   None,
#   1.4677829092123167,
#   'Software Developers, Systems Software'),
#  ('contingent project assistant',
#   None,
#   0.7300887843207193,
#   'Computer User Support Specialists'),
#  ('business partner',
#   'Marketing Managers',
#   2.3372112209183147,
#   'Marketing Managers'),
#  ('all source analyst watch officer',
#   'Intelligence Analysts',
#   3.411208084111092,
#   'Intelligence Analysts'),
#  ('program management specialist',
#   'Software Developers, Systems Software',
#   1.506438117194062,
#   'Management Analysts'),
#  ('quality analyst with ts sci',
#   None,
#   0.8316666906187538,
#   'Software Developers, Applications'),
#  ('channel systems engineer mid',
#   'Network and Computer Systems Administrators',
#   2.290254102730919,
#   'Information Security Analysts'),
#  ('sigint multi int analyst',
#   'Intelligence Analysts',
#   1.729178615767125,
#   'Intelligence Analysts'),
#  ('registered nurse ii admissions suite night shift',
#   'Registered Nurses',
#   2.578834332678155,
#   'Registered Nurses'),
#  ('director technology solutions',
#   'Management Analysts',
#   1.6203410924763113,
#   'Marketing Managers'),
#  ('waf coordinator',
#   None,
#   0.6519334836876426,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('software engineer salesforce',
#   'Software Developers, Applications',
#   2.9282051614009856,
#   'Software Developers, Applications'),
#  ('admin support assistant',
#   'Information Security Analysts',
#   2.3357880339798407,
#   'Intelligence Analysts'),
#  ('sr developer telework',
#   'Information Security Analysts',
#   1.5063482926374743,
#   'Web Developers'),
#  ('abac systems engineer active directory',
#   'Software Developers, Applications',
#   2.620392617874164,
#   'Software Developers, Systems Software'),
#  ('software development analyst',
#   'Software Developers, Systems Software',
#   1.502781357582812,
#   'Software Developers, Applications'),
#  ('manager security engineering',
#   'Information Security Analysts',
#   2.27449920826352,
#   'Information Security Analysts'),
#  ('provisioning specialist order management procurement telecom',
#   'Network and Computer Systems Administrators',
#   1.5048507889117684,
#   'Customer Service Representatives'),
#  ('shipping and transportation specialist',
#   None,
#   0.8270712948902806,
#   'Maintenance and Repair Workers, General'),
#  ('assistant program manager', None, 1.4591872624357158, 'Nursing Assistants'),
#  ('automotive internet sales consultant',
#   'Retail Salespersons',
#   3.3956380154018335,
#   'Retail Salespersons'),
#  ('network tier iii engineer senior',
#   'Network and Computer Systems Administrators',
#   2.4282681330140745,
#   'Financial Analysts'),
#  ('emergency room rn inova flexible shifts',
#   'Registered Nurses',
#   4.169506419545328,
#   'Nursing Assistants'),
#  ('application security engineer',
#   'Information Security Analysts',
#   3.136069606707093,
#   'Information Security Analysts'),
#  ('software asset management specialist',
#   'Information Security Analysts',
#   1.6670936216120977,
#   'Software Developers, Applications'),
#  ('software programmer sr developer',
#   'Network and Computer Systems Administrators',
#   1.6516549910526264,
#   'Software Developers, Applications'),
#  ('systems engineer devops',
#   'Software Developers, Applications',
#   3.0794826462432203,
#   'Software Developers, Applications'),
#  ('bus info developer consultant sr',
#   'Software Developers, Applications',
#   2.613823569673912,
#   'Management Analysts'),
#  ('sales associate peppers rd',
#   'Retail Salespersons',
#   3.8256183655643747,
#   'Retail Salespersons'),
#  ('asset manager', None, 0.7787995040585236, 'Intelligence Analysts'),
#  ('it capabilities management support analyst',
#   'Information Security Analysts',
#   1.543071764888328,
#   'Management Analysts'),
#  ('management systems ems engineer with ts sci clearance',
#   'Software Developers, Systems Software',
#   2.656259289379681,
#   'Network and Computer Systems Administrators'),
#  ('system integrator administrator top secret sci',
#   'Network and Computer Systems Administrators',
#   1.6337797983511204,
#   'Network and Computer Systems Administrators'),
#  ('procurement data entry administrator',
#   'Computer User Support Specialists',
#   1.5468253565709618,
#   'Management Analysts'),
#  ('claims wfm analyst i ii sr',
#   'General and Operations Managers',
#   1.5286335002906757,
#   'Management Analysts'),
#  ('principal risk associate application and data management team',
#   'Financial Managers, Branch or Department',
#   1.6040333045845947,
#   'Financial Managers, Branch or Department'),
#  ('information assurance engineer ii w ts sci poly clearance',
#   'Information Security Analysts',
#   3.6125480657427556,
#   'Information Security Analysts'),
#  ('service manager professional services',
#   None,
#   0.7791821602497347,
#   'Information Security Analysts'),
#  ('acquisition logistics specialist i',
#   'Management Analysts',
#   1.5286802879197796,
#   'Management Analysts'),
#  ('registered nurse rn labor and delivery float pool prn nights',
#   'Registered Nurses',
#   3.7612616595086728,
#   'Registered Nurses'),
#  ('technical support electrical technician',
#   'Software Developers, Systems Software',
#   1.5934695198550481,
#   'Software Developers, Systems Software'),
#  ('integrated network support ins technical acss mcnosc',
#   'Network and Computer Systems Administrators',
#   4.612992000997607,
#   'Network and Computer Systems Administrators'),
#  ('gehc engineering technician iii',
#   None,
#   0.8253429449487693,
#   'Software Developers, Applications'),
#  ('free space optical scientist engineer',
#   'Software Developers, Systems Software',
#   4.0167026864250515,
#   'Computer User Support Specialists'),
#  ('team leader performance evaluation of the enhancing the status of human rights',
#   'Computer User Support Specialists',
#   2.8600415869495,
#   'Marketing Managers'),
#  ('commercial communications analyst',
#   None,
#   1.469735556203196,
#   'Software Developers, Systems Software'),
#  ('executive assistant to the chief human resources officer',
#   None,
#   0.8895613192596575,
#   'Marketing Managers'),
#  ('apc sentara vascular specialists',
#   None,
#   1.4616920530404753,
#   'Registered Nurses'),
#  ('security engineer senior',
#   'Information Security Analysts',
#   2.884177561189892,
#   'Software Developers, Systems Software'),
#  ('project ux design',
#   None,
#   1.456844198389362,
#   'Software Developers, Applications'),
#  ('shrm temporary certification research analyst',
#   'Information Security Analysts',
#   2.2815387473422097,
#   'Software Developers, Systems Software'),
#  ('trusted electronics technology consultant',
#   'Information Security Analysts',
#   1.5669754198529113,
#   'Software Developers, Systems Software'),
#  ('electromagnetic specialist emp',
#   None,
#   0.8665590128044622,
#   'Computer Systems Analysts'),
#  ('retail team leader williamsburgh prem',
#   'General and Operations Managers',
#   2.484613409062818,
#   'General and Operations Managers'),
#  ('geoint engineer ft',
#   'Intelligence Analysts',
#   2.4312501378899496,
#   'Computer User Support Specialists'),
#  ('sales training opportunity',
#   None,
#   0.7404586727358932,
#   'Customer Service Representatives'),
#  ('electronic files specialist',
#   None,
#   1.450866500282664,
#   'Information Security Analysts'),
#  ('macys backstage team member flexible scheduling option part dulles dulles town',
#   'Retail Salespersons',
#   3.7223484214550604,
#   'Customer Service Representatives'),
#  ('specialist senior principal',
#   None,
#   1.4448676369702562,
#   'Intelligence Analysts'),
#  ('contract assistant',
#   None,
#   0.7153495895917833,
#   'Network and Computer Systems Administrators'),
#  ('food service director ii',
#   None,
#   0.8428469627447702,
#   'Maintenance and Repair Workers, General'),
#  ('loss prevention manager',
#   'General and Operations Managers',
#   1.7860356033365823,
#   'Information Security Analysts'),
#  ('senior strategic planning and performance evaluation analyst',
#   'Intelligence Analysts',
#   1.74440871111897,
#   'Intelligence Analysts'),
#  ('hbss security engineer',
#   'Information Security Analysts',
#   1.6035158742190447,
#   'Information Security Analysts'),
#  ('service engine technician',
#   None,
#   0.8432962183373456,
#   'Maintenance and Repair Workers, General'),
#  ('bench hr manager',
#   'General and Operations Managers',
#   1.6019849209848722,
#   'General and Operations Managers'),
#  ('nmcc drsn voice data engineer',
#   'Network and Computer Systems Administrators',
#   1.5559838679673916,
#   'Software Developers, Systems Software'),
#  ('sales associate customer service repair technician',
#   'Automotive Specialty Technicians',
#   1.6628074192714326,
#   'Automotive Specialty Technicians'),
#  ('requirements analyst w polygraph',
#   'Software Developers, Systems Software',
#   2.36092860755382,
#   'Intelligence Analysts'),
#  ('registered nurse anesthesia care unit rn pacu',
#   'Registered Nurses',
#   2.660446415860262,
#   'Registered Nurses'),
#  ('presentation team leader',
#   'General and Operations Managers',
#   2.399935234986613,
#   'Retail Salespersons'),
#  ('senior process manager',
#   None,
#   0.7390217921104337,
#   'General and Operations Managers'),
#  ('systems engineer level',
#   None,
#   1.482105241609725,
#   'Software Developers, Systems Software'),
#  ('access identity manager developer job',
#   'Software Developers, Systems Software',
#   2.359613147894856,
#   'Information Security Analysts'),
#  ('senior director product management',
#   'Marketing Managers',
#   2.3756123101117512,
#   'Marketing Managers'),
#  ('network operations engineer',
#   'Network and Computer Systems Administrators',
#   1.5203322732447127,
#   'Network and Computer Systems Administrators'),
#  ('bedding specialist', None, 1.3561072092097297, 'Retail Salespersons'),
#  ('vice president corporate finance',
#   'Financial Managers, Branch or Department',
#   1.754486183879497,
#   'Financial Managers, Branch or Department'),
#  ('registered nurse night shift',
#   'Registered Nurses',
#   3.4252138729542967,
#   'Registered Nurses'),
#  ('team software engineer',
#   'Software Developers, Applications',
#   2.985990859241678,
#   'Software Developers, Applications'),
#  ('him site supervisor',
#   'General and Operations Managers',
#   1.5692829574831713,
#   'Registered Nurses'),
#  ('recruitment officer',
#   None,
#   0.7372073010397779,
#   'Information Security Analysts'),
#  ('customer service associate appliances',
#   'Retail Salespersons',
#   2.4854274943802865,
#   'Retail Salespersons'),
#  ('warehouse assistant part',
#   None,
#   0.7327203008032314,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('princ systems administrator ts sci reqd',
#   'Network and Computer Systems Administrators',
#   3.636843840864894,
#   'Network and Computer Systems Administrators'),
#  ('class b cdl driver shot crew member',
#   'Heavy and Tractor-Trailer Truck Drivers',
#   4.527150110607469,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('business process analyst',
#   'Management Analysts',
#   2.397142159628477,
#   'Management Analysts'),
#  ('software engineer faa',
#   'Software Developers, Systems Software',
#   2.0447288500697898,
#   'Software Developers, Applications'),
#  ('security business operations manager',
#   'Information Security Analysts',
#   1.5255178477406872,
#   'Sales Managers'),
#  ('software quality assurance analyst',
#   'Software Developers, Applications',
#   1.65807224357876,
#   'Software Developers, Systems Software'),
#  ('transaction advisory services senior transaction tax mergers acquisitions',
#   'Financial Managers, Branch or Department',
#   2.6585927795128828,
#   'Financial Managers, Branch or Department'),
#  ('management services',
#   None,
#   1.4027525316894156,
#   'Customer Service Representatives'),
#  ('neural interface consultant',
#   None,
#   1.446640043404971,
#   'Financial Analysts'),
#  ('federal architecture manager',
#   'Software Developers, Applications',
#   3.169559980713391,
#   'Computer Systems Analysts'),
#  ('retail marketing manager',
#   'Marketing Managers',
#   2.1907213324773593,
#   'Marketing Managers'),
#  ('clinical operations supervisor holter',
#   'General and Operations Managers',
#   2.2334464609589935,
#   'Customer Service Representatives'),
#  ('rn neuro icu', 'Registered Nurses', 3.31288779449853, 'Registered Nurses'),
#  ('supervisor office',
#   None,
#   1.462630596104963,
#   'General and Operations Managers'),
#  ('cyber security analyst staff',
#   'Information Security Analysts',
#   1.5951242125448288,
#   'Information Security Analysts'),
#  ('registered nurse pediatrics prn',
#   'Registered Nurses',
#   2.4534746793274986,
#   'Registered Nurses'),
#  ('financial fellow', None, 0.7885200684816766, 'Financial Analysts'),
#  ('patient care supervisor',
#   'Nursing Assistants',
#   2.3876617534891436,
#   'Registered Nurses'),
#  ('technical writer editor top secret clearance',
#   'Intelligence Analysts',
#   2.7301303334710427,
#   'Computer Systems Analysts'),
#  ('registered nurse rn medical surgical icu sign on bonus up to',
#   'Registered Nurses',
#   3.757914786269533,
#   'Registered Nurses'),
#  ('federal channel sales representative system integrators',
#   'Marketing Managers',
#   2.542164917042201,
#   'Marketing Managers'),
#  ('systems operations specialist',
#   None,
#   1.4378010202489764,
#   'Network and Computer Systems Administrators'),
#  ('physical scientist gs deu bb',
#   'Automotive Specialty Technicians',
#   1.6182060647201935,
#   'Software Developers, Systems Software'),
#  ('management specialist ii p',
#   'Information Security Analysts',
#   1.5538952591813582,
#   'Retail Salespersons'),
#  ('senior performance test engineer',
#   'Software Developers, Applications',
#   1.6335886969074909,
#   'Software Developers, Applications'),
#  ('hr data analyst', None, 1.4480253587326104, 'Management Analysts'),
#  ('sr iasp target analyst reporter',
#   'Intelligence Analysts',
#   3.2628735594919966,
#   'Intelligence Analysts'),
#  ('senior soa developers',
#   None,
#   0.8163423669677554,
#   'Software Developers, Applications'),
#  ('client service administrator db',
#   'Customer Service Representatives',
#   1.5332835764511208,
#   'General and Operations Managers'),
#  ('web marketing coordinator',
#   'Marketing Managers',
#   3.113083929677405,
#   'Marketing Managers'),
#  ('web assistant', None, 1.3508462783590953, 'Marketing Managers'),
#  ('automotive finance insurance manager',
#   'Financial Managers, Branch or Department',
#   1.6083862895756191,
#   'Retail Salespersons'),
#  ('certification and accreditation officer',
#   'Information Security Analysts',
#   4.44006639319059,
#   'Information Security Analysts'),
#  ('business systems consultant security analytics',
#   'Computer Systems Analysts',
#   1.5421773143710449,
#   'Information Security Analysts'),
#  ('senior strategy and assessments leader',
#   None,
#   1.4833029012678445,
#   'Software Developers, Systems Software'),
#  ('senior system administrator',
#   'Network and Computer Systems Administrators',
#   2.9846576900355974,
#   'Network and Computer Systems Administrators'),
#  ('registered nurse progressive care unit',
#   'Registered Nurses',
#   4.462971252067253,
#   'Registered Nurses'),
#  ('retail sales part s lynnhaven mall',
#   'Retail Salespersons',
#   2.7676831310169185,
#   'General and Operations Managers'),
#  ('sr major account executive',
#   'Sales Managers',
#   2.493806374314877,
#   'Sales Managers'),
#  ('management and team members',
#   None,
#   0.7440076726994859,
#   'Retail Salespersons'),
#  ('emergency department tech ed tech',
#   'Registered Nurses',
#   3.392603683402143,
#   'Registered Nurses'),
#  ('route sales rep commission',
#   'Heavy and Tractor-Trailer Truck Drivers',
#   3.256681237512968,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('shift supervisor us',
#   'Retail Salespersons',
#   1.603372688259196,
#   'General and Operations Managers'),
#  ('dag support officer',
#   'Intelligence Analysts',
#   1.572914085046743,
#   'Intelligence Analysts'),
#  ('cloud information system security engineer isse job',
#   'Information Security Analysts',
#   4.1866315163566945,
#   'Information Security Analysts'),
#  ('patient services coord',
#   'Registered Nurses',
#   3.185418853967433,
#   'Registered Nurses'),
#  ('medical office specialist call',
#   'Customer Service Representatives',
#   2.528949407752833,
#   'Customer Service Representatives'),
#  ('unit generalist sr position unit',
#   'Financial Managers, Branch or Department',
#   1.6519220430331076,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('apparel coordinator supervisory role',
#   'Retail Salespersons',
#   2.169913870054587,
#   'General and Operations Managers'),
#  ('cyber security sme analyst',
#   'Information Security Analysts',
#   3.860500050565387,
#   'Intelligence Analysts'),
#  ('technical field specialist',
#   'Network and Computer Systems Administrators',
#   2.2147496781546065,
#   'Software Developers, Applications'),
#  ('pt operations admin cust service',
#   'General and Operations Managers',
#   1.6091021865964734,
#   'Retail Salespersons'),
#  ('deskstop engineer',
#   None,
#   1.16644828066566,
#   'Computer User Support Specialists'),
#  ('manager hotel accounting',
#   'Financial Managers, Branch or Department',
#   3.00601764492472,
#   'Financial Managers, Branch or Department'),
#  ('registered nurse trauma icu night shift',
#   'Registered Nurses',
#   3.525120809734875,
#   'Registered Nurses'),
#  ('project dispatcher',
#   None,
#   0.773024866593934,
#   'Computer User Support Specialists'),
#  ('business technology consultant life sciences consulting fall northwestern',
#   'Management Analysts',
#   1.6457427173750447,
#   'Management Analysts'),
#  ('intelligence analyst sr',
#   'Intelligence Analysts',
#   3.689059419935799,
#   'Intelligence Analysts'),
#  ('sr developer job',
#   'Software Developers, Applications',
#   2.1905090993316776,
#   'Software Developers, Applications'),
#  ('senior data warehousing specialist',
#   None,
#   1.4570821627259392,
#   'Software Developers, Applications'),
#  ('princ info security analyst ts sci reqd',
#   'Information Security Analysts',
#   3.693549024312983,
#   'Information Security Analysts'),
#  ('senior software engineer developer',
#   'Software Developers, Applications',
#   2.3710187062538552,
#   'Software Developers, Applications'),
#  ('rn mother infant unit',
#   'Registered Nurses',
#   4.107999790977251,
#   'Registered Nurses'),
#  ('team collections', None, 1.4619314313844982, 'Sales Managers'),
#  ('clinical technician orthopedic',
#   'Registered Nurses',
#   3.8136789026670685,
#   'Registered Nurses'),
#  ('matrix senior engineer', None, 1.284114624444, 'Management Analysts'),
#  ('sds mct help desk team manager proprietary systems specialist must have nato secret iat ii job',
#   'Network and Computer Systems Administrators',
#   4.82209985556995,
#   'Network and Computer Systems Administrators'),
#  ('program management specialist senior district',
#   None,
#   0.8390345142219655,
#   'Computer Systems Analysts'),
#  ('safety and environmental specialist',
#   None,
#   0.820573119738639,
#   'General and Operations Managers'),
#  ('information security risk program analyst ii',
#   'Information Security Analysts',
#   1.633934124674055,
#   'Information Security Analysts'),
#  ('general sports sales leader',
#   'Retail Salespersons',
#   2.3955476253685655,
#   'Customer Service Representatives'),
#  ('program analyst technical job',
#   'Computer Systems Analysts',
#   1.5346147520330808,
#   'Management Analysts'),
#  ('advanced practice nurse practitioner',
#   'Registered Nurses',
#   3.52104837469958,
#   'Registered Nurses'),
#  ('store manager fww',
#   'General and Operations Managers',
#   2.9938566378483267,
#   'Sales Managers'),
#  ('market research analysts and marketing specialists',
#   None,
#   0.8207965840359884,
#   'Marketing Managers'),
#  ('social analyst ts sci w polygraph',
#   'Network and Computer Systems Administrators',
#   3.4416378980141005,
#   'Software Developers, Applications'),
#  ('chief sw engineer',
#   'Software Developers, Applications',
#   1.5458883752113812,
#   'Software Developers, Applications'),
#  ('analyst medicaid ra', None, 1.1785403299473662, 'Management Analysts'),
#  ('senior manager of systems aws object storage and messaging',
#   'Software Developers, Applications',
#   1.6213496076198335,
#   'Software Developers, Applications'),
#  ('technical targeting analyst tta',
#   'Intelligence Analysts',
#   3.2382627099883887,
#   'Intelligence Analysts'),
#  ('rn maryview nursing care',
#   'Registered Nurses',
#   4.116155265203468,
#   'Registered Nurses'),
#  ('o m system administrator job',
#   'Software Developers, Systems Software',
#   1.7988939677383255,
#   'Network and Computer Systems Administrators'),
#  ('property management services manager',
#   'Sales Managers',
#   1.6052470269467305,
#   'Software Developers, Systems Software'),
#  ('part credit sos coordinator',
#   None,
#   0.9403769255403871,
#   'Retail Salespersons'),
#  ('food service manager',
#   'Registered Nurses',
#   1.5390676308590403,
#   'General and Operations Managers'),
#  ('control room officer',
#   None,
#   1.4924784259439525,
#   'Customer Service Representatives'),
#  ('sr finance analyst',
#   'Financial Analysts',
#   2.3097499404590702,
#   'Financial Analysts'),
#  ('burner technician',
#   None,
#   1.286744104131753,
#   'Maintenance and Repair Workers, General'),
#  ('rn ortho ft nights',
#   'Registered Nurses',
#   4.052712758436735,
#   'Registered Nurses'),
#  ('registered nurse full shift full part',
#   'Registered Nurses',
#   4.410731710069498,
#   'Registered Nurses'),
#  ('senior telecommunications specialist',
#   'Software Developers, Systems Software',
#   1.550421323552917,
#   'Software Developers, Systems Software'),
#  ('sr marketing manager',
#   'Marketing Managers',
#   3.6987631760596775,
#   'Management Analysts'),
#  ('document management analyst',
#   'Information Security Analysts',
#   1.663768014106782,
#   'Software Developers, Systems Software'),
#  ('cyber security incident response web risk analyst government',
#   'Information Security Analysts',
#   3.5459256735851072,
#   'Information Security Analysts'),
#  ('aws engineer needed for financial tech company',
#   'Network and Computer Systems Administrators',
#   1.6087068241896039,
#   'Software Developers, Applications'),
#  ('supervisor customer service',
#   None,
#   0.7651487635915035,
#   'Retail Salespersons'),
#  ('administrator contract military',
#   None,
#   1.4606588425820037,
#   'Financial Managers, Branch or Department'),
#  ('jcids information management support analyst p',
#   'Computer Systems Analysts',
#   1.7539786969086812,
#   'Computer Systems Analysts'),
#  ('legal assistant ii', None, 0.8490621051818691, 'Management Analysts'),
#  ('senior intelligence analyst p',
#   'Intelligence Analysts',
#   3.8693690886977095,
#   'Intelligence Analysts'),
#  ('account manager r', 'Sales Managers', 2.9012121399337825, 'Sales Managers'),
#  ('field service professional',
#   None,
#   0.8092472063520703,
#   'Maintenance and Repair Workers, General'),
#  ('technical program manager ii',
#   None,
#   1.4947942202108913,
#   'Software Developers, Systems Software'),
#  ('senior manager small business',
#   'Marketing Managers',
#   1.6015721160395973,
#   'Registered Nurses'),
#  ('inn express sales coordinator',
#   None,
#   0.8118952933936774,
#   'Customer Service Representatives'),
#  ('computer systems analyst',
#   'Information Security Analysts',
#   1.5317904753879819,
#   'Computer Systems Analysts'),
#  ('private company services manager',
#   'Financial Managers, Branch or Department',
#   2.291580157079621,
#   'Financial Managers, Branch or Department'),
#  ('systems engineer it sr',
#   'Software Developers, Systems Software',
#   1.5558155944705627,
#   'Network and Computer Systems Administrators'),
#  ('senior accountant for a technology firm lc',
#   'Financial Managers, Branch or Department',
#   2.4992409847508,
#   'Financial Managers, Branch or Department'),
#  ('senior director it transformation service',
#   'Marketing Managers',
#   1.5251531110196108,
#   'Marketing Managers'),
#  ('facilities planner senior',
#   'Software Developers, Systems Software',
#   1.532518561664786,
#   'Information Security Analysts'),
#  ('target researcher and technical targeter',
#   'Intelligence Analysts',
#   3.3586648101438796,
#   'Intelligence Analysts'),
#  ('supervisory it specialist plcypln',
#   'Computer User Support Specialists',
#   2.4613473359316664,
#   'Automotive Specialty Technicians'),
#  ('project registered architects s t experience',
#   None,
#   0.860137534519809,
#   'Software Developers, Applications'),
#  ('network engineer i',
#   'Network and Computer Systems Administrators',
#   2.862682456673884,
#   'Network and Computer Systems Administrators'),
#  ('sigint systems engineer cleared',
#   'Software Developers, Systems Software',
#   1.5971065517471543,
#   'Software Developers, Systems Software'),
#  ('customer account manager cam',
#   'Sales Managers',
#   2.181394154609614,
#   'Software Developers, Systems Software'),
#  ('faa program analyst',
#   'Computer Systems Analysts',
#   2.087937360068086,
#   'Information Security Analysts'),
#  ('public sector practice project finance support',
#   'Financial Managers, Branch or Department',
#   2.530209979449126,
#   'Financial Analysts'),
#  ('information assurance specialist all levels',
#   None,
#   0.8496350257007934,
#   'Information Security Analysts'),
#  ('manager multiple positions',
#   None,
#   0.8088735345581839,
#   'Computer Systems Analysts'),
#  ('certified occupational therapist assistant cota ft',
#   'Registered Nurses',
#   3.4370975532068098,
#   'Software Developers, Systems Software'),
#  ('clothing and equipment acquisition support specialist',
#   'Management Analysts',
#   2.5162885746408348,
#   'Management Analysts'),
#  ('over the road otr team truck driver',
#   'Heavy and Tractor-Trailer Truck Drivers',
#   4.202132271731765,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('accounts management specialist',
#   None,
#   1.4996035619831174,
#   'Network and Computer Systems Administrators'),
#  ('product go to market manager',
#   'Marketing Managers',
#   3.3999407795931633,
#   'Marketing Managers'),
#  ('certified nursing aide cna',
#   'Nursing Assistants',
#   3.5521828105200037,
#   'Registered Nurses'),
#  ('senior call performance specialist',
#   'Customer Service Representatives',
#   1.5399353930675617,
#   'Management Analysts'),
#  ('senior insider threat analyst',
#   'Intelligence Analysts',
#   1.7193179721543745,
#   'Intelligence Analysts'),
#  ('licensed practical nurse lpn pt days river pointe',
#   'Registered Nurses',
#   2.826902701974608,
#   'Registered Nurses'),
#  ('tax senior manager partnership',
#   'Financial Managers, Branch or Department',
#   2.3749062624463866,
#   'Financial Managers, Branch or Department'),
#  ('clinical nurse',
#   'Registered Nurses',
#   2.2026915129062132,
#   'Registered Nurses'),
#  ('pt member service representative call',
#   'Customer Service Representatives',
#   3.387907685845563,
#   'Financial Managers, Branch or Department'),
#  ('assistant manager investor reporting',
#   'Financial Managers, Branch or Department',
#   2.236253940189502,
#   'Financial Analysts'),
#  ('intotal health medicaid managed term services and support project manager',
#   None,
#   0.846994894270337,
#   'Marketing Managers'),
#  ('vice president information systems',
#   'General and Operations Managers',
#   1.6891719232118771,
#   'Financial Managers, Branch or Department'),
#  ('senior electrician', None, 0.7974403298811846, 'Management Analysts'),
#  ('director of operations',
#   'Management Analysts',
#   1.610396689589673,
#   'General and Operations Managers'),
#  ('assistant dir nursing',
#   'Nursing Assistants',
#   2.3280944609852754,
#   'Registered Nurses'),
#  ('cybersecurity analyst windows',
#   'Information Security Analysts',
#   3.0378588458991858,
#   'Software Developers, Applications'),
#  ('dasd systems engineer senior specialist',
#   'Software Developers, Systems Software',
#   3.297198989169827,
#   'Software Developers, Systems Software'),
#  ('asset management specialist',
#   'Information Security Analysts',
#   1.6055825516792765,
#   'Computer Systems Analysts'),
#  ('senior cyber director leve',
#   None,
#   0.7255608561934519,
#   'Information Security Analysts'),
#  ('pki sharepoint engineer',
#   'Network and Computer Systems Administrators',
#   1.562026573031679,
#   'Web Developers'),
#  ('it services cto',
#   None,
#   1.4857407566152034,
#   'Software Developers, Systems Software'),
#  ('nutrition support dietitian',
#   'Nursing Assistants',
#   1.562866283500139,
#   'Financial Analysts'),
#  ('afcec project program leader',
#   None,
#   0.7580807651257263,
#   'Software Developers, Systems Software'),
#  ('bilingual spanish administrative assistant multiple',
#   'Retail Salespersons',
#   2.44474836349528,
#   'Sales Managers'),
#  ('federal territory account manager',
#   'Sales Managers',
#   3.306284117015143,
#   'Marketing Managers'),
#  ('associate client executive mid market',
#   'Marketing Managers',
#   1.5884327704406203,
#   'Sales Managers'),
#  ('technical support expert job',
#   'Software Developers, Applications',
#   2.3175909656297504,
# ...
#   2.110131857489163,
#   'Maintenance and Repair Workers, General'),
#  ('test engineer database interface technical tester',
#   'Management Analysts',
#   1.6297079436030995,
#   'Software Developers, Applications'),
#  ('system administrator data operations',
#   'Network and Computer Systems Administrators',
#   3.760530526730941,
#   'Network and Computer Systems Administrators'),
#  ('computer vision engineer',
#   None,
#   1.4732358502218788,
#   'Software Developers, Systems Software'),
#  ('nsw shipping receiving customer service representative p',
#   None,
#   0.8599868648509112,
#   'General and Operations Managers'),
#  ('senior manager proposals',
#   None,
#   1.2922264536664252,
#   'Information Security Analysts'),
#  ('it specialist appsw',
#   'Computer Systems Analysts',
#   1.6839324111276999,
#   'Computer User Support Specialists'),
#  ('vice president business development federal domestic programs',
#   'Marketing Managers',
#   2.6228282454005116,
#   'Sales Managers'),
#  ('retail merchandising associate on call',
#   'Information Security Analysts',
#   1.5804959370839233,
#   'Retail Salespersons'),
#  ('manager accounts payable',
#   None,
#   0.8514874443295148,
#   'Financial Managers, Branch or Department'),
#  ('staffing consultant', None, 1.4691868004737878, 'Sales Managers'),
#  ('project conus chief engineer',
#   None,
#   1.4951318519478363,
#   'Information Security Analysts'),
#  ('associate solutions architect',
#   'Software Developers, Applications',
#   2.3713237531547042,
#   'Information Security Analysts'),
#  ('electro tech',
#   'Software Developers, Systems Software',
#   2.145924523031601,
#   'Maintenance and Repair Workers, General'),
#  ('graduate technical',
#   'Registered Nurses',
#   2.893062493618436,
#   'Software Developers, Systems Software'),
#  ('commercial maintenance technician',
#   'Maintenance and Repair Workers, General',
#   2.3066036177640408,
#   'Maintenance and Repair Workers, General'),
#  ('business financial analyst mid',
#   'Financial Analysts',
#   2.375215960583433,
#   'Financial Analysts'),
#  ('federal big data senior analyst',
#   'Software Developers, Applications',
#   1.6401728058885334,
#   'Software Developers, Applications'),
#  ('information system security engineer isse',
#   'Information Security Analysts',
#   4.1866315163566945,
#   'Information Security Analysts'),
#  ('it specialist plcypln entarch associate chief architect',
#   None,
#   1.4799582198927816,
#   'Computer Systems Analysts'),
#  ('development', 'Marketing Managers', 1.953609030338603, 'Web Developers'),
#  ('retail district manager',
#   'General and Operations Managers',
#   1.5161343873739277,
#   'Marketing Managers'),
#  ('supervisor payment services administration',
#   'Registered Nurses',
#   2.3418554148992534,
#   'Customer Service Representatives'),
#  ('cybersecurity program manager',
#   'Software Developers, Systems Software',
#   1.5195840590629217,
#   'Information Security Analysts'),
#  ('team cyber security engineer senior level engineer analyst',
#   'Information Security Analysts',
#   4.17168399372162,
#   'Information Security Analysts'),
#  ('marketing analytics principal associate',
#   'Marketing Managers',
#   3.9202069051983317,
#   'Marketing Managers'),
#  ('professional development program pdp business management supply chain grad',
#   'Software Developers, Systems Software',
#   1.8791117386312215,
#   'Marketing Managers'),
#  ('business analyst iii business consultant job family',
#   'Management Analysts',
#   1.7241926380373753,
#   'Management Analysts'),
#  ('network operations network performance active dhs eod and secret clearance job',
#   'Network and Computer Systems Administrators',
#   3.6321742966004855,
#   'Automotive Specialty Technicians'),
#  ('mortgage loan officer mlo',
#   'Financial Managers, Branch or Department',
#   1.5169489472078008,
#   'Financial Managers, Branch or Department'),
#  ('rn peri operative internship operating room full days',
#   'Registered Nurses',
#   4.430386732638903,
#   'Registered Nurses'),
#  ('joint incident awareness and assessment team jit analyst',
#   'Information Security Analysts',
#   2.3833533457099363,
#   'Intelligence Analysts'),
#  ('it security manager',
#   'Information Security Analysts',
#   2.957651451786444,
#   'Information Security Analysts'),
#  ('patient services liaison',
#   'Registered Nurses',
#   2.218878477395601,
#   'Nursing Assistants'),
#  ('diesel technician mechanic roadside assistance',
#   'Automotive Specialty Technicians',
#   2.5750130651704124,
#   'Automotive Specialty Technicians'),
#  ('int account executive',
#   'Marketing Managers',
#   3.1583513980546547,
#   'Sales Managers'),
#  ('information assurance analyst c a',
#   'Information Security Analysts',
#   3.4197373085529676,
#   'Information Security Analysts'),
#  ('epic cert systems analyst sr meaningful use',
#   'Computer Systems Analysts',
#   3.5035981215886727,
#   'Computer Systems Analysts'),
#  ('facilities administrative assistant',
#   'Maintenance and Repair Workers, General',
#   2.3894353187490305,
#   'Automotive Specialty Technicians'),
#  ('cyber inside program manager',
#   'General and Operations Managers',
#   1.5376863895440613,
#   'Information Security Analysts'),
#  ('health manager np',
#   None,
#   1.4582308305412162,
#   'General and Operations Managers'),
#  ('engineering fellow',
#   None,
#   1.4339928855812323,
#   'Information Security Analysts'),
#  ('senior software engineer for a high end consulting firm',
#   'Software Developers, Applications',
#   2.4280267184150954,
#   'Software Developers, Applications'),
#  ('cardiology technician ecg',
#   'Nursing Assistants',
#   2.1861623980863607,
#   'Registered Nurses'),
#  ('manager compliance control',
#   None,
#   1.4779220610730857,
#   'Financial Managers, Branch or Department'),
#  ('product service owner ii',
#   'Marketing Managers',
#   2.3812862802270027,
#   'General and Operations Managers'),
#  ('service desk specialist network operation technician sign on bonus',
#   'Registered Nurses',
#   2.6045564215272132,
#   'Management Analysts'),
#  ('director of care coordination signature partners network',
#   'Registered Nurses',
#   2.3847685787974284,
#   'Registered Nurses'),
#  ('rn charge nurse l d shift',
#   'Registered Nurses',
#   4.471749131837088,
#   'Registered Nurses'),
#  ('public sector channel business development manager',
#   None,
#   0.8800346810796862,
#   'Sales Managers'),
#  ('business initiatives consultant',
#   'Management Analysts',
#   2.188315008046078,
#   'Management Analysts'),
#  ('business quality analyst top secret clearance',
#   'Information Security Analysts',
#   3.504475383024067,
#   'Computer Systems Analysts'),
#  ('registered nurse specialty',
#   'Registered Nurses',
#   3.923496224063649,
#   'Registered Nurses'),
#  ('telecommunications project manager',
#   'Network and Computer Systems Administrators',
#   2.992240855341014,
#   'Network and Computer Systems Administrators'),
#  ('unmanned aerial systems analyst',
#   'Software Developers, Systems Software',
#   3.694464569845902,
#   'Software Developers, Systems Software'),
#  ('edm configuration management specialist',
#   'Management Analysts',
#   1.6479071241865888,
#   'Network and Computer Systems Administrators'),
#  ('data analyst government',
#   None,
#   1.4943543690723735,
#   'Network and Computer Systems Administrators'),
#  ('integrations engineer',
#   'Software Developers, Applications',
#   1.9087658946854937,
#   'Software Developers, Applications'),
#  ('produce team member',
#   'Retail Salespersons',
#   3.9661508996281,
#   'Retail Salespersons'),
#  ('software requirements analyst senior',
#   'Software Developers, Applications',
#   1.5665823353675155,
#   'Software Developers, Systems Software'),
#  ('counter d d outreach coordinator',
#   'Software Developers, Applications',
#   1.6759955469346477,
#   'Intelligence Analysts'),
#  ('susa patrol officer colonial hgts',
#   None,
#   1.4960418063863081,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('asst store mgr commonwealth blvd',
#   'Retail Salespersons',
#   1.851148983625054,
#   'General and Operations Managers'),
#  ('software systems test engineer',
#   'Software Developers, Applications',
#   1.5844740962940984,
#   'Network and Computer Systems Administrators'),
#  ('public sector project management manager',
#   'Management Analysts',
#   1.691689044766909,
#   'Marketing Managers'),
#  ('programmer analyst specialist documentum',
#   'Software Developers, Applications',
#   1.5311681898954739,
#   'Computer Systems Analysts'),
#  ('consulting practice director strategy and portfolio',
#   'Marketing Managers',
#   1.6564185423299422,
#   'Marketing Managers'),
#  ('lpn licensed practical nurse per diem part',
#   'Registered Nurses',
#   2.756725833999716,
#   'Registered Nurses'),
#  ('sca administrative assistant',
#   None,
#   0.8550089908674245,
#   'Computer Systems Analysts'),
#  ('engineer systems test mcms',
#   'Software Developers, Systems Software',
#   2.3370641427981242,
#   'Software Developers, Systems Software'),
#  ('it project manager ts sci with poly required',
#   'Software Developers, Systems Software',
#   1.8517739181939805,
#   'Software Developers, Systems Software'),
#  ('firearms technical sales associates',
#   'Retail Salespersons',
#   2.5022199972243184,
#   'Retail Salespersons'),
#  ('territory sales representative',
#   'Marketing Managers',
#   1.6380085738347845,
#   'Sales Managers'),
#  ('mgr hiv clinic',
#   'Registered Nurses',
#   3.684598358125072,
#   'Registered Nurses'),
#  ('program assistant', None, 1.4591872624357158, 'Marketing Managers'),
#  ('machine learning software engineer',
#   'Software Developers, Systems Software',
#   1.8061408147588165,
#   'Software Developers, Systems Software'),
#  ('management trainee jiffy lube service jiffy lube service',
#   'Automotive Specialty Technicians',
#   2.9737527260039753,
#   'Customer Service Representatives'),
#  ('network operations engineer level',
#   'Network and Computer Systems Administrators',
#   2.283256923534413,
#   'Network and Computer Systems Administrators'),
#  ('health unit coordinator transitional care hospital',
#   'Registered Nurses',
#   3.5072570179073224,
#   'Nursing Assistants'),
#  ('customer service rep south street',
#   'Retail Salespersons',
#   2.6274554666077408,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('federal big data consultant',
#   None,
#   0.8251391645718554,
#   'Software Developers, Applications'),
#  ('sr developer amazon herndonjobs amazon com',
#   'Software Developers, Systems Software',
#   2.685813507310437,
#   'Software Developers, Systems Software'),
#  ('manager ii information assur',
#   None,
#   1.424221474234463,
#   'Information Security Analysts'),
#  ('and agreements supervisor',
#   None,
#   0.7159029916041356,
#   'General and Operations Managers'),
#  ('case management business analyst',
#   'Registered Nurses',
#   1.5508631774567634,
#   'Marketing Managers'),
#  ('sharepoint architect team',
#   'Web Developers',
#   2.3000746859175516,
#   'Web Developers'),
#  ('voice data communications engineer',
#   'Network and Computer Systems Administrators',
#   2.311004323090594,
#   'Network and Computer Systems Administrators'),
#  ('call specialist',
#   'Customer Service Representatives',
#   1.5399353930675617,
#   'Customer Service Representatives'),
#  ('firewall design engineer',
#   'Information Security Analysts',
#   3.1206706270769766,
#   'Information Security Analysts'),
#  ('dispatcher customer service representative',
#   'Customer Service Representatives',
#   1.62595127384241,
#   'Heavy and Tractor-Trailer Truck Drivers'),
#  ('governance manager senior',
#   None,
#   0.7676741148372743,
#   'Software Developers, Systems Software'),
#  ('supervisor corporate claims',
#   None,
#   1.431018067248932,
#   'General and Operations Managers'),
#  ('rehab registered nurse',
#   'Registered Nurses',
#   3.2220584044534246,
#   'Registered Nurses'),
#  ('cloud software engineer',
#   'Software Developers, Applications',
#   3.6874447085003776,
#   'Software Developers, Applications'),
#  ('director of ticket operations and guest services international raceway',
#   'Marketing Managers',
#   2.535822100047955,
#   'Sales Managers'),
#  ('business systems analyst technical specialist',
#   'Software Developers, Systems Software',
#   1.5253513691113991,
#   'Computer Systems Analysts'),
#  ('software developer computer scientist',
#   'Software Developers, Applications',
#   2.4640816967023724,
#   'Software Developers, Systems Software'),
#  ('sr net c software developer ts sci ft',
#   'Software Developers, Applications',
#   2.699970054561433,
#   'Web Developers'),
#  ('critical care float rn travel position',
#   'Registered Nurses',
#   4.302976879059742,
#   'Registered Nurses'),
#  ('lpn outpatient inova urgent care every other weeken',
#   'Registered Nurses',
#   2.7967497362943807,
#   'Registered Nurses'),
#  ('medical economics mgr', None, 1.384164891667544, 'Management Analysts'),
#  ('anti terorism physical security countermeasures contingency planning officer w polygraph',
#   'Information Security Analysts',
#   2.4781854657634863,
#   'Information Security Analysts'),
#  ('information assurance security architect',
#   'Information Security Analysts',
#   3.2488769455990294,
#   'Information Security Analysts'),
#  ('senior program management analyst',
#   'Software Developers, Systems Software',
#   1.5202212336172893,
#   'Management Analysts'),
#  ('mgr facilities and real estate',
#   None,
#   0.892401314073555,
#   'General and Operations Managers'),
#  ('business analyst with healthcare',
#   None,
#   1.4825026975127102,
#   'Management Analysts'),
#  ('accs senior system administrator',
#   'Network and Computer Systems Administrators',
#   2.377012463278743,
#   'Network and Computer Systems Administrators'),
#  ('web publishing specialist contractor',
#   None,
#   0.7172197809789783,
#   'Software Developers, Applications'),
#  ('secl student production technician i fall semester',
#   None,
#   0.7813833055638781,
#   'General and Operations Managers'),
#  ('assistant manager outlet corner',
#   'General and Operations Managers',
#   2.4863137948181047,
#   'General and Operations Managers'),
#  ('ui engineer multiple locations',
#   'Financial Managers, Branch or Department',
#   1.6660194181227008,
#   'Web Developers'),
#  ('access control administrator',
#   None,
#   1.3883431334022858,
#   'Network and Computer Systems Administrators'),
#  ('finance analyst mid',
#   'Financial Analysts',
#   2.9780825895713203,
#   'Financial Analysts'),
#  ('medical call manager',
#   'Customer Service Representatives',
#   1.602340097096604,
#   'Management Analysts'),
#  ('geoint staff officer',
#   'Intelligence Analysts',
#   1.5587475986678623,
#   'Intelligence Analysts'),
#  ('information technology specialist level',
#   'Network and Computer Systems Administrators',
#   1.6421400696537938,
#   'Software Developers, Systems Software'),
#  ('primary care nurse practitioner physician assistant',
#   'Registered Nurses',
#   1.8326689710321973,
#   'Registered Nurses'),
#  ('it desktop virtualization architect senior',
#   'Network and Computer Systems Administrators',
#   1.5784199443983562,
#   'Network and Computer Systems Administrators'),
#  ('vice president finance operations',
#   'General and Operations Managers',
#   2.6525367471690346,
#   'Marketing Managers'),
#  ('care partner',
#   'Registered Nurses',
#   3.0979580101471798,
#   'Registered Nurses'),
#  ('director of applications business',
#   'Marketing Managers',
#   2.3735907845634694,
#   'Maintenance and Repair Workers, General'),
#  ('occupational health lpn inova hospital prn part',
#   'Registered Nurses',
#   2.602872652504245,
#   'Registered Nurses'),
#  ('senior logistics analyst',
#   None,
#   1.4880010383955657,
#   'Software Developers, Systems Software'),
#  ('senior recruitment branding',
#   None,
#   1.276859403281415,
#   'Marketing Managers'),
#  ('orbital analyst', None, 1.1785403299473662, 'Intelligence Analysts'),
#  ('transfer ctr bed coordinator',
#   'Registered Nurses',
#   2.1800969807655783,
#   'Registered Nurses'),
#  ('benefits admin associate project based oe',
#   'Customer Service Representatives',
#   3.3925494182975706,
#   'Management Analysts'),
#  ('systems security administrator info systems security officer isso',
#   'Information Security Analysts',
#   1.824748889552012,
#   'Information Security Analysts'),
#  ('applications and reporting analyst',
#   None,
#   0.7727591691319269,
#   'Management Analysts'),
#  ('management analyst ii revenue budget',
#   None,
#   0.8519819669777915,
#   'Financial Analysts'),
#  ...]

# %% [markdown]
# > Let's see how many examples haven't passed the threshold, the recall and precision

# %%
import copy

def evaluate(dataset: List[Tuple], label_list) -> int:
    
    pos = {_label: 0 for _label in label_list}
    monitor = {_label: {"pos": 0, "neg": 0} for _label in label_list}
    for _d in dataset:
        query, pred, score, label = _d
        pos[label] += 1
        if pred:
            if pred == label:
                monitor[label]["pos"] += 1
            else:
                monitor[pred]["neg"] += 1
    rec = {l: score["pos"] * 1.0 / pos[l] for l, score in monitor.items()}
    prec = {l: score["pos"] * 1.0 / (score["pos"] + score["neg"]) for l, score in monitor.items()}
    return rec, prec

# %%
eval_results = evaluate(response, label_list)

# %%
rec, prec = eval_results

# %%
rec
# Out:
# {'General and Operations Managers': 0.14965986394557823,
#  'Marketing Managers': 0.3435897435897436,
#  'Sales Managers': 0.2857142857142857,
#  'Financial Managers, Branch or Department': 0.42592592592592593,
#  'Management Analysts': 0.27167630057803466,
#  'Financial Analysts': 0.25,
#  'Computer Systems Analysts': 0.14545454545454545,
#  'Information Security Analysts': 0.5133079847908745,
#  'Software Developers, Applications': 0.45925925925925926,
#  'Software Developers, Systems Software': 0.24796747967479674,
#  'Web Developers': 0.16326530612244897,
#  'Network and Computer Systems Administrators': 0.5,
#  'Computer User Support Specialists': 0.19101123595505617,
#  'Registered Nurses': 0.7777777777777778,
#  'Nursing Assistants': 0.2,
#  'Intelligence Analysts': 0.5067567567567568,
#  'Retail Salespersons': 0.43119266055045874,
#  'Customer Service Representatives': 0.33695652173913043,
#  'Automotive Specialty Technicians': 0.41379310344827586,
#  'Maintenance and Repair Workers, General': 0.2564102564102564,
#  'Heavy and Tractor-Trailer Truck Drivers': 0.25806451612903225}

# %%
def visualize(recall: List[float], precision: List[float]):
    x1 = np.array(recall)
    x2 = np.array(precision)
    
    data = [x1, x2]
    group_labels = ["recall", "precision"]
    fig = ff.create_distplot(data, group_labels, show_hist=False)
    
    return fig

# %%
fig = visualize(list(rec.values()), list(prec.values()))

# %%
fig.show()
